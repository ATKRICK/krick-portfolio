# %% [markdown]
# Andrew Krick
#
# Training a deep neural network on the CIFAR10 image
# dataset:

# %% [markdown]
# Build a DNN with 20 hidden layers of 100 neurons each
# (that’s too many, but it’s the point of this exercise). Use
# He initialization and the swish activation function.

# %%
# Create a Deep Neural Network (DDN).
# 20 hidden layers of 100 nearons each.
# That is too many but its the point of the excise
# Use 'HE initialization' and the 'Swish activation' function.

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Define the model
model = keras.Sequential()

# Input layer
model.add(layers.Input(shape=(32, 32, 3)))

# 20 hidden layers with 100 neurons each
# Use 'He' initialization and 'Swish' activation.
for _ in range(20):
    model.add(layers.Dense(100, kernel_initializer='he_normal'))
    model.add(layers.Activation(tf.nn.swish))

# Output layer (10 classes for CIFAR10)
model.add(layers.Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                      │ (None, 32, 32, 100)         │             400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 32, 32, 100)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32, 32, 100)         │          10,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 32, 32, 100)         │               0 │
# ...

# %% [markdown]
# Using early stopping, training the network on the CIFAR10
# dataset. You can load it with
# tf.keras.datasets.cifar10.load_data() (I suggest consulting
# the appropriate documentation for how to load properly
# load this data into your environment). The dataset is
# composed of 60,000 32 × 32–pixel color images (50,000 for
# training, 10,000 for testing) with 10 classes, so you’ll
# need a softmax output layer with 10 neurons. Remember to
# search for the right learning rate each time you change the
# model’s architecture or hyperparameters

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping

# Load dataset and preprocess CIFAR10 dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Normalize pixel values range of [0,1]
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Convert labels to one-hot encoding for the softmax layer
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
# Define model.
model = keras.Sequential()
model.add(layers.Input(shape=(32, 32, 3)))

# Add a Flatten layer to convert the image to a 1D vector
model.add(layers.Flatten())

for _ in range(20):
    model.add(layers.Dense(100, kernel_initializer='he_normal'))
    # Replace 'HeNormalization' with 'BatchNormalization'
    # as 'HeNormalization' is not a valid Keras layer.
    # HeNormalization is a technique for weight initialization, not a layer.
    model.add(layers.BatchNormalization())
    model.add(layers.Activation(tf.nn.softmax))

model.add(layers.Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Find the right learning rate
def build_and_train_model(learning_rate):
    # Compile the model inside the function
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    history = model.fit(x_train, y_train, epochs=100, batch_size=32,
                        validation_data=(x_test, y_test),
                        callbacks=[early_stopping])
    return history, model

# Plot the learning curves
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Learning Curves with he_norm Normalization')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# We can see here that the training accuracy isn't a very smooth curve like we would want to see. Validation is rigid with rises and falls. Not a very accurate model for the dataset.

# %% [markdown]
#  Now try adding Batch Normalization and compare the
# learning curves: Is it converging faster than before? Does
# it produce a better model? How does it affect training
# speed

# %% [markdown]
# The training speed takes much longer, but the accuracy scores and loss are improved significantly. The Batch chart has a much smoother curve and the validation curve is less rigid but not smooth.

# %%
# Define model using Batch Normalization
model = keras.Sequential()
model.add(layers.Input(shape=(32, 32, 3)))

# Flatten the input
model.add(layers.Flatten())

# Load and preprocess CIFAR10 dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

for _ in range(20):
    model.add(layers.Dense(100, kernel_initializer='he_normal'))
    model.add(layers.BatchNormalization())  # add batch normalization
    model.add(layers.Activation(tf.nn.swish))

model.add(layers.Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model with early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Increase epochs for better comparison, 100 epochs
history = model.fit(x_train, y_train, epochs=100, batch_size=32,
                    validation_data=(x_test, y_test),
                    callbacks=[early_stopping])

# Plot the learning curves
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Learning Curves with Batch Normalization')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 52s 21ms/step - accuracy: 0.2284 - loss: 2.1035 - val_accuracy: 0.3209 - val_loss: 1.9007
# Epoch 2/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 39s 19ms/step - accuracy: 0.3802 - loss: 1.7354 - val_accuracy: 0.3802 - val_loss: 1.7502
# Epoch 3/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 42s 20ms/step - accuracy: 0.4166 - loss: 1.6395 - val_accuracy: 0.3495 - val_loss: 1.8664
# Epoch 4/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 39s 19ms/step - accuracy: 0.4390 - loss: 1.5822 - val_accuracy: 0.4183 - val_loss: 1.6429
# Epoch 5/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 40s 18ms/step - accuracy: 0.4629 - loss: 1.5240 - val_accuracy: 0.4223 - val_loss: 1.6447
# Epoch 6/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 42s 19ms/step - accuracy: 0.4766 - loss: 1.4770 - val_accuracy: 0.4166 - val_loss: 1.6481
# Epoch 7/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.4966 - loss: 1.4274 - val_accuracy: 0.4201 - val_loss: 1.6410
# Epoch 8/100
# ...

# %% [markdown]
#  Try replacing Batch Normalization with SELU, and make the
# necessary adjustments to ensure the network self-normalizes (i.e., standardize the input features, use LeCun
# normal initialization, make sure the DNN contains only a
# sequence of dense layers). How does the performance
# change?

# %% [markdown]
# The peformance does change from Batch/Swish to SELU/LeCun. SELU/LeCun is less accurate with an accuracy score of 60%. Batch/Swish had an accuracy score of 65%. The charts reflect a lot of inaccuracy. The line goes rigid in places having significant drops in data accuracy.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Define model using SELU Normalization
model = keras.Sequential()
model.add(layers.Input(shape=(32, 32, 3)))

# Flatten the input
model.add(layers.Flatten())

# Load and preprocess CIFAR10 dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# Standardize input features
x_train_mean = x_train.mean(axis=0)
x_train_std = x_train.std(axis=0)
x_train = (x_train - x_train_mean) / x_train_std
x_test = (x_test - x_train_mean) / x_train_std

for _ in range(20):
    model.add(layers.Dense(100, kernel_initializer='lecun_normal', activation='selu'))

model.add(layers.Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model with early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Increase epochs for better comparison, 50 epochs
history = model.fit(x_train, y_train, epochs=100, batch_size=32,
                    validation_data=(x_test, y_test),
                    callbacks=[early_stopping])

# Plot the learning curves
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Learning Curves with SELU Normalization')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 29s 14ms/step - accuracy: 0.2441 - loss: 2.0986 - val_accuracy: 0.3402 - val_loss: 1.8161
# Epoch 2/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - accuracy: 0.3538 - loss: 1.7904 - val_accuracy: 0.3817 - val_loss: 1.7427
# Epoch 3/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - accuracy: 0.3899 - loss: 1.7003 - val_accuracy: 0.4126 - val_loss: 1.6472
# Epoch 4/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - accuracy: 0.4203 - loss: 1.6286 - val_accuracy: 0.4390 - val_loss: 1.5951
# Epoch 5/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - accuracy: 0.4263 - loss: 1.5993 - val_accuracy: 0.4096 - val_loss: 1.6118
# Epoch 6/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - accuracy: 0.4509 - loss: 1.5470 - val_accuracy: 0.4552 - val_loss: 1.5717
# Epoch 7/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - accuracy: 0.4697 - loss: 1.5003 - val_accuracy: 0.4618 - val_loss: 1.5288
# Epoch 8/100
# ...
